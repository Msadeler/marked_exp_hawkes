# %%
from functions.hawkes_process import *
from functions.GOF import *
from functions.compensator import *
from functions.multivariate_exponential_process import *
from functions.estimator_class_multi_rep import *
import scipy

# %%
np.random.seed(0)

# %% [markdown]
# ### Simulation of a Marked Exponential Hawkes Process

# %% [markdown]
# We start by simulating a unidimensional Hawkes process denoted $N$. The intensity of the process is given by the formula: $\begin{equation} \lambda(t) = m + \int_{(-\infty ,t)\times \mathcal{E} } a e^{-b(t-s)} \phi_{\gamma, \psi}(\kappa) N(ds \times d\kappa), \end{equation}$
#
#
# with $\kappa$ being an i.i.d. random variable with a c.d.f. $F_\psi$, admitting a density $f_\psi$.

# %%
np.random.seed(0)

m, a, b = 1, -1, 2

## taking kappa i.i.d following a exponential distribution of parameter 1
def F(mark,psi):
    return(scipy.stats.expon.ppf(mark, scale = psi))

def phi(mark, gamma, psi):
    return((psi-gamma)/psi*np.exp(mark*gamma))

def f(mark,psi):
    return(psi*np.exp(-psi*mark))


hawkes = exp_thinning_hawkes_marked(m=m,
                                    a=a, 
                                    b=b, 
                                    F = F ,
                                    arg_F = {'psi':1.2},
                                    phi=phi, 
                                    arg_phi = {'gamma': 1},
                                    max_jumps = 5 )


hawkes.simulate()

fig, ax = plt.subplots(2,1, figsize=(7,7))
hawkes.plot_intensity(ax =ax)

#fig.savefig('plot/simulation_MEHP.png')

# %% [markdown]
# We now consider a multidimensional Hawkes process for which the intensity $\lambda_i$ of the i-th subprocess takes the form: $\begin{equation} \lambda_{i}(t) = m_i + \sum_{j=1}^{d} \int_{(-\infty ,t)\times \mathcal{E}} a_{ij} e^{-b_i(t-s)} \phi_{\gamma, \psi}(\kappa) N^j(ds \times d\kappa), \end{equation}$
#
# with $\kappa$ being an i.i.d. random variable with a c.d.f. $F_\psi$, admitting a density $f_\psi$.

# %%
np.random.seed(0)

m = np.array([0.5, 0.2]).reshape((2,1))
a = np.array([[0.4, 0.2,], 
                  [-0.4, 0.3]] )
b = np.array([[1],[1.5]])


def F(mark,psi):
    return(scipy.stats.expon.ppf(mark, scale = psi))

def phi(mark, gamma, psi):
    return((psi-gamma)/psi*np.exp(mark*gamma))

def f(mark,psi):
    return(psi*np.exp(-psi*mark))


hawkes_multi = multivariate_exponential_hawkes_marked(m=m,
                                                      a=a, 
                                                      b=b, 
                                                      phi = phi, 
                                                      F= F, 
                                                      arg_phi={'gamma':1}, 
                                                      arg_F={'psi': 2}, 
                                                      max_jumps  = 5)

hawkes_multi.simulate()

fig,ax = plt.subplots(2,2, figsize = (10,10))
hawkes_multi.plot_intensity(ax = ax)

# %% [markdown]
# # Apply testing procedure on several samples

# %% [markdown]
# We present here the code used to apply different test procedures on a Hawkes process. To that end, we start by simulating a synthetic dataset containing 500 repetitions of a Hawkes process.

# %%
np.random.seed(0)

m=1
a = -1
b = 1

## simulation 
hawkes_multi = exp_thinning_hawkes_multi_marked(m=m,
                                    a=a, 
                                    b=b, 
                                    n=200,
                                    max_jumps=500)
hawkes_multi.simulate()

# %%
print(f'Correspond to Tmax = {np.mean([x[-1] for x in hawkes_multi.timeList])}')
# Out:
# Correspond to Tmax = 973.9496828617106

# %% [markdown]
# ## Test on the coefficients of the model
#
# ### Test of a specific value for one coefficient

# %%
learner_hawkes = estimator_unidim_multi_rep(a_bound = None,
                                            bound_b = None)
learner_hawkes.fit(hawkes_multi.timeList, max_jump = True)

# %% [markdown]
# Hypothesis under test: $\mathcal{H}_0 : m = 1 \quad \text{ vs } \quad \mathcal{H}_1 : m \ne 1$.

# %%
stat = learner_hawkes.test_one_coeff( coefficient_index=0, value = 1,plot=True)

# %% [markdown]
# Hypothesis under test: $\mathcal{H}_0 : a = -1 \quad \text{ vs } \quad \mathcal{H}_1 : a \ne -1$.

# %%
stat = learner_hawkes.test_one_coeff(coefficient_index=1,value=-1, plot = True)
# Out:
# No theoretical garantee associated to this test

# %% [markdown]
# ### Test of equality between coefficients

# %% [markdown]
# Hypothesis under test: $\mathcal{H}_0 : a = m \quad \text{ vs } \quad \mathcal{H}_1 : a \ne m$.

# %%
stat = learner_hawkes.test_equality_coeff(coefficient_index_1=0,coefficient_index_2=1, plot = True)

# %% [markdown]
# ## Test on the model used for estimation
# We present here different tests on the model associated with the data, relying on the GOF procedure.
#
# ### Test of the self-exciting qssumption
#
# Hypothesis under test: $\mathcal{H}_0 : \text{Data are i.i.d. representations of a Poisson model with an unknown parameter}$

# %%
## Simulation done with Hawkes process with inhibition and test performed for a Poisson process

learner_poisson = estimator_unidim_multi_rep(loss = likelihood_Poisson)
learner_poisson.fit(hawkes_multi.timeList,max_jump = True)
stats_poisson = learner_poisson.GOF_bootstrap(compensator_func=poisson_compensator,
                                              test_type = 'uniform', 
                                              Nb_SubSample=100, 
                                              plot = True)

# %% [markdown]
# We compare this result to the one obtain when testing the following null hypothesis.
#  $$\mathcal{H}_0 : \text{data are i.i.d represetation of a Hawkes model } $$

# %%
## Simulation done with Hawkes process with inhibition and test performed for a Hawkes process

stat_hawkes = learner_hawkes.GOF_bootstrap(test_type = 'uniform', 
                            Nb_SubSample=100, 
                            plot = True)

# %% [markdown]
# ### Test of the inhibition assumption

# %% [markdown]
# We test here the null hypothesis $$\mathcal{H}_0 : \text{data are i.i.d represetation of a Hawkes model without inhibition} $$

# %%
## Simulation done with Hawkes process with inhibition and test performed for a Hawkes process without inhibition

learner_hawkes_ex = estimator_unidim_multi_rep(a_bound=0)
learner_hawkes_ex.fit(hawkes_multi.timeList , max_jump = True)
stats_hawkes_ex = learner_hawkes_ex.GOF_bootstrap(compensator_func=unidim_EHP_compensator,
                                              test_type = 'uniform', 
                                              Nb_SubSample=50, 
                                              plot = True)

# %% [markdown]
# ### Test of the marked assumpation

# %% [markdown]
# We test here the null hypothesis :  $$\mathcal{H}_0 : \text{data are i.i.d represetation of a marked Hawkes model} $$

# %%
from functions.paramtrised_function import *

np.random.seed(0)

m,a,b = 1, -1, 2


hawkes = exp_thinning_hawkes_multi_marked(m=m,
                                        a=a, 
                                        b=b, 
                                        mark_process=True,
                                        F=F, 
                                        arg_F={'psi':2}, 
                                        phi=phi, 
                                        arg_phi={'gamma':1}, 
                                        max_jumps=500, 
                                        n=200)
hawkes.simulate()

learner = estimator_unidim_multi_rep(mark=True, 
                                     f=f, 
                                    name_arg_f=['psi'], 
                                    phi=phi, 
                                    name_arg_phi=['gamma'], 
                                    bound_f=[(1e-5, None)], 
                                    bound_phi=[(None,None)], 
                                    initial_guess_f=[1], 
                                    initial_guess_phi=[0])

learner.fit(hawkes.timeList)
# Out:
# array([ 2.00655076,  1.05669193,  1.01245299, -1.1146453 ,  2.05129891])

# %%
stats_hawkes_ex = learner.GOF_bootstrap(compensator_func=unidim_MEHP_compensator,
                                              test_type = 'uniform', 
                                              Nb_SubSample=50, 
                                              plot = True)

# %% [markdown]
# # Apply test when one repetition is available

# %% [markdown]
# Univariate case:

# %%
### generation of a hawkes process with one repetition 
from functions.estimator_class import *
from functions.hawkes_process import *

np.random.seed(0)

m, a, b = 1, 0.5, 1

hawkes = exp_thinning_hawkes_marked(m=m,
                                    a=a, 
                                    b=b,
                                    max_time=2000 
                                    )
hawkes.simulate()
# Out:
# /home/sadelerm/Bureau/Hawkes/functions/LogLikHessian.py:383: SyntaxWarning: invalid escape sequence '\ '
#   """

# %%
estimator = loglikelihood_estimator()
estimator.fit(hawkes.timestamps, max_time=True)
estimator.test_one_coeff(coefficient_index = 0
                         ,value= 1)
# Out:
# {'stat': 0.09480592031056008, 'pval': 0.9244689843288412}

# %% [markdown]
# Multivariate case:

# %%
from functions.multivariate_exponential_process import *
from functions.estimator_class import *

np.random.seed(0)

m = np.array([0.5, 0.2]).reshape((2,1))
a = np.array([[0.4, 0.2,], 
                  [0.4, 0.3]] )
b = np.array([[1],[1]])



hawkes_multi = multivariate_exponential_hawkes(m=m,
                                                a=a, 
                                                b=b, 
                                                max_jumps  = 1000)

hawkes_multi.simulate()

# %%
estimator = multivariate_estimator(dimension=2)
estimator.fit(hawkes_multi.timestamps, max_jump=True)
estimator.test_equality_coeff(coefficient_index_1 =7,coefficient_index_2=6)
# Out:
# {'stat': np.float64(0.17840323416532525),
#  'pval': np.float64(0.8584063095532211)}

# %% [markdown]
# # Real dataset

# %% [markdown]
# #### Earthquake data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import functions as hp
# Out:
# R[write to console]: De plus :
# R[write to console]: Message d'avis :
#
# R[write to console]: Dans (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  les bibliothèques ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ ne contiennent aucun package

# %%
data_earthquake = pd.read_csv('real_data/ogata.csv', index_col=0).loc[:, ['time', 'magnitude']]
data_tuple = [(0,0)] +list(data_earthquake.itertuples(index=False, name = None)) +  [(800,0)]

# %% [markdown]
# ##### Data description

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

ax[1].hist(data_earthquake['magnitude'])
ax[1].set_xlabel('Magnitude')

ax[0].step(data_earthquake['time'], data_earthquake.index, '-o', markersize = 4, where= "post")
ax[0].set_xlabel('Time')
ax[0].set_ylabel(r'N(t)')
# Out:
# Text(0, 0.5, 'N(t)')

# %% [markdown]
# ##### Bootstrap test

# %%
def rec_formula(t, m,a,b,arg_f,arg_phi, phi, timebefore, intensity_last_jump, time_transformed):
    return( time_transformed+ m*(t-timebefore[0])+ (1-np.exp(-b*(t-timebefore[0])))*(intensity_last_jump+a*phi(timebefore[1], **arg_phi, **arg_f)-m)/b )

rec_formula = rec_formula

from functions.paramtrised_function import *

bval = 500

estimator = hp.estimator_bootstrap(mark=True,
                            name_arg_f=['psi'], 
                                name_arg_phi=['gamma'], 
                                f=f,
                                F=F,
                                phi=phi,
                                initial_guess_f = [1], 
                                initial_guess_phi = [0], 
                                bound_phi = [(1e-5, None)],
                                bound_f = [(1e-5,None)]
                                )
estimator.boostrap_procedure( tlist =data_tuple, B=bval,max_time=True,rec_formula=rec_formula)
# Out:
# Start bootsrap simulation
# 100%|██████████| 500/500 [00:01<00:00, 338.50it/s]
# End bootsrap simulation

# %%
estimator.test_one_coeff(coefficient_index=1, value=0)
# Out:
# {'stat': 2.373302318759164, 'quantile': 1.959963984540054}

# %% [markdown]
# #### Neuronal data

# %% [markdown]
# We analyze data from the [Zhang & al, 2023](https://www.sciencedirect.com/science/article/pii/S2589004223002778) study of neural activity in mice. In this experiment, several mice explore a circular arena in search of rewards, while their neural activity, position, speed and direction are recorded. Each recording comprises five sessions, considered as independent repetitions of the process.
#
# We only look into a part of the dataset, which is composed of the recording $140605$ of the mouse $M22$ but the all dataset can be founded here : https://doi.gin.g-node.org/10.12751/g-node.xbr77j/

# %% [markdown]
# ##### Data description

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import functions as hp

data_param_estim = []
mouse='M22'
recording = '140605'


Nav = pd.read_csv(f"neuro_data/data/{mouse}/{recording}/Nav_{mouse}_{recording}.csv")
Spk =  pd.read_csv(f"neuro_data/data/{mouse}/{recording}/Spk_{mouse}_{recording}.csv")
CellInfo = pd.read_csv(f"neuro_data/data/{mouse}/{recording}/CellInfo_{mouse}_{recording}.csv")
# Out:
# R[write to console]: De plus :
# R[write to console]: Message d'avis :
#
# R[write to console]: Dans (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  les bibliothèques ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ ne contiennent aucun package

# %%
session = 1
cell = 7

Spk['SampleTimes']= Spk['SpikeTimes'].apply(lambda x : round(x,2))
position_spk = Nav.loc[ (Nav['SampleTimes'].isin( Spk.loc[Spk.ClusterIDs==cell, 'SampleTimes'].tolist())) & (Nav.session == session), ['X', 'Y'] ]


plt.figure(figsize=(5,5))
plt.clf()
plt.scatter( position_spk['X'],  position_spk['Y'], c='green', marker='.',linewidth = 0.5)
plt.plot( np.array(Nav.loc[Nav.session == session, 'X' ]), np.array(Nav.loc[Nav.session == session, 'Y' ]), color = 'grey', linewidth = 1, alpha = 0.6)
plt.title(f"Trajectory of the mouse {mouse} during session {session} of recording {recording} with spike location of neuron {cell}")
# Out:
# Text(0.5, 1.0, 'Trajectory of the mouse M22 during session 1 of recording 140605 with spike location of neuron 7')

# %% [markdown]
# ##### The point process

# %%
good_cluster = (CellInfo.loc[CellInfo.GoodCluster ==1 ,:].index +1).tolist() #### Use only Neurons that are labelled "good cluster"
cluster_ordered = [k+1 for k in range(len(good_cluster))]

Spk = Spk.loc[Spk['ClusterIDs'].isin(good_cluster).tolist(),:]
Spk['ClusterIDs'] = Spk['ClusterIDs'].map(dict(zip(good_cluster,cluster_ordered)))

#### Compute the number of spike 
Spk = Spk.loc[Spk['ClusterIDs'].isin([k+1 for k in range(len(good_cluster))]).tolist(),:] 
Spk['unit'] = Spk['SpikeTimes'].apply(lambda x : round(x//200) )
z = Spk.groupby(['ClusterIDs', 'unit']).agg(len).reset_index()

Session = Nav.groupby(['session']).agg({'SampleTimes':['min', 'max']}).values.reshape((5,2))
Tmax =np.min(Session[:,1]-Session[:,0])

k=0
l=-1
plot_val = Spk.loc[(Spk['SpikeTimes'] <=Session[k,1] )& (Spk['SpikeTimes'] >=Session[k,0] ), :]
plot_val.loc[:,'SpikeTimes'] = plot_val.loc[:,'SpikeTimes'] - Session[k,0]

# %%
fig, ax = plt.subplots(1,2, figsize=(7,5))

for cluster in cluster_ordered:
    jjump_neuron = plot_val.iloc[:l,:].loc[plot_val.ClusterIDs ==cluster,:]
    data = z.loc[z.ClusterIDs ==cluster, :]
    ax[1].plot(data.unit, data.SpikeTimes, '-o',label=f'Neuron{cluster}' )
    ax[0].step( jjump_neuron['SpikeTimes'],[k for k in range(len(jjump_neuron))],'-o', markersize = 4, where= "post", label=f"Neuron{k}")
    
ax[0].set_xlabel('time')
lgd =ax[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# We thus delete neuron 2 wich is not stationnary.

# %% [markdown]
# #####

# %%
Spk = Spk.loc[Spk['ClusterIDs']!= 2 ,:]
Spk.loc[Spk.ClusterIDs >=3  , 'ClusterIDs'] = Spk.loc[Spk.ClusterIDs >=3  , 'ClusterIDs']-1

cluster_set = np.unique(Spk.ClusterIDs)

# %% [markdown]
# ##### Fitting data

# %%
time_list = []
## Data with time of each spike

for k in range(5):
    time_session = Spk.loc[(Spk['SpikeTimes'] <=Session[k,1] )& (Spk['SpikeTimes'] >=Session[k,0] ), ['SpikeTimes', 'ClusterIDs']]
    time_session.loc[:,'SpikeTimes'] = time_session.loc[:,'SpikeTimes'] - Session[k,0]
    time_session = [(0,0)] + list(time_session.itertuples(index=False, name=None)) + [(Session[k,1]- Session[k,0], 0)]
    time_list += [time_session]

#%%

learner = hp.estimator_multidim_multi_rep(dimension=len(cluster_set),mark=False)
learner.fit(time_list,max_time=True)
# Out:
# array([ 2.32520528e-02,  7.11790892e-01,  2.99741599e-01,  3.97614538e-01,
#        -2.54630213e-01, -3.15391545e-03, -2.07849104e-03,  9.55649787e-03,
#        -4.32634781e-01,  3.16259896e+00,  7.21182481e-02,  1.89069820e+00,
#        -5.43234142e-01, -9.92122927e-03,  1.39337716e+00, -2.38617850e-02,
#        -1.19769546e-01,  9.93369060e-01, -2.16259131e-03,  8.70994391e-01,
#         1.47170091e+00,  6.45431241e+00,  2.52319997e+00,  6.49355836e+00])

# %%
time_change = [hp.multi_EHP_compensator(time_list[k], learner.mean_MLE) for k in range(len(time_list))]
# Out:
# 0.209155332067783 2
# 0.529751179505979 3
# 0.0539997963701353 4
# 2.2892119617004028 4
# 0.9172808268399422 4

# %%
sss = hp.multi_EHP_compensator(time_list[0], learner.mean_MLE)
# Out:
# 0.209155332067783 2

# %%
time_change[0][0]
# Out:
# [0.5629436057374407,
#  0.95818256028129,
#  4.2385469024429385,
#  0.2763072608420261,
#  0.06058924097838582,
#  1.9617758048022444,
#  0.709660143191122,
#  0.7889776943600385]

# %%
def aggregated_process(timeslists: list):
    
    ### aggregate all process given
    aggList = [0.0]
    for times in timeslists:
        aggList += [aggList[-1] + i for i in times]

    ## delete the time corresponding to Lambd(Tmax) that are not actual jump time
    end_times = np.cumsum([len(times) for times in timeslists])
    max_obs_time = aggList[-1]
    
    aggList = np.array([aggList[k] for k in np.arange(end_times[-1]) if k not in end_times])
    
    return aggList,max_obs_time

# %%
data = []

for neuron in range(len(cluster_ordered)):
    
    data +=[aggregated_process([np.cumsum(time_change[k][neuron]) for k in  range(len(time_change))])[0]]

# %%
import scipy.stats


for i in range(len(cluster_ordered)):
    print(hp.qq_conf_test( data[i][2:-1] - data[i][1:-2] , distribution=scipy.stats.expon.ppf, plot = False ))
    print(kstest(data[i][1:] - data[i][:-1], cdf = "expon").pvalue)
# Out:
# False
# 0.04559778298973583
# False
# 0.0001608009653338748
# False
# 0.03268376233892267
# False
# 0.21762999073746514
# False
# 1.587931540954254e-06

# %%
from scipy.stats import kstest
kstest(data[i][1:] - data[i][:-1], cdf = "expon")
# Out:
# KstestResult(statistic=0.144527263849901, pvalue=0.04559778298973583, statistic_location=0.24731983132859625, statistic_sign=1)
